# %%
from Expo_Reg import Expo_Reg
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5, 6, 7]
y = [2.5, 3.8, 4.2, 5.5, 7.0, 8.2, 10.0]

expo = Expo_Reg(x,y)

y_pred = []

expo.calculate_m_value()
expo.calculate_b_value()
expo.exp_calculate_m_value()
expo.exp_calculate_b_value()

y_pred = expo.calc_reg_arr()
expo.print_Funktion()



print(y_pred[0])

# Linien für die Vorhersagen
# Punktwolke für die Trainingsdaten
plt.scatter(x, y, color='orange', label='Training')
# Graph für die Vorhersagen der Trainingsdaten
plt.plot(x, y_pred, color='blue', label='Predicted Testdata')
# Beschriftung der X-Achse
plt.xlabel('x')
# Beschriftung der Y-Achse
plt.ylabel('x')
# Titel
plt.title('Lineare Regression mit Linear_')
# Legende anzeigen
plt.legend()

plt.ticklabel_format(axis='y', style='plain', useOffset=False)

plt.show()
# Out:
# Die Funktion lautet: y = 2.2052162165077536 * 1.2482135744138791 ^x
# 2.752580815962594

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# Beispiel-Daten
X = np.array([1, 2, 3, 4, 5, 6, 7])
Y = np.array([2.5, 3.8, 4.2, 5.5, 7.0, 8.2, 10.0])

# Daten transformieren
log_Y = np.log(Y)

# Regressionsmodell erstellen und trainieren
model = LinearRegression()
X = X.reshape(-1, 1)  # Scikit-Learn erwartet 2D-Array für die Features
model.fit(X, log_Y)

# Koeffizienten des Modells
slope = model.coef_[0]  # Koeffizient für X (Steigung)
intercept = model.intercept_  # Konstante (y-Achsenabschnitt)

# Parameter für die exponentielle Funktion
base = np.e  # Die Basis des Exponenten
a = np.exp(intercept)  # Parameter a in der exponentiellen Funktion (y = a * base^(slope * X))

print("Steigung (slope):", slope)
print("Konstante (intercept):", intercept)
print("Parameter a:", a)

# Ergebnisse anzeigen
print("Vorhersagen:", predictions)

# Originaldaten und Regressionsgerade plotten
plt.scatter(X, Y, label="Daten")
plt.plot(X, np.exp(model.predict(X)), color='red', label="Regressionsgerade")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.show()
# Out:
# Steigung (slope): 0.22171338865004986
# Konstante (intercept): 0.7908255614646307
# Parameter a: 2.2052162165077545
# Vorhersagen: [ 8.34035593 10.41054549 12.9945842 ]
